# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
import torch
from torchvision import datasets,transforms,models
from torch import nn, optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {"train":transforms.Compose([transforms.RandomRotation(30),
                                   transforms.RandomResizedCrop(224),
                                   transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485,0.456,0.406],
                                                    [0.229,0.224,0.225])]),
                   "validation":transforms.Compose([transforms.RandomRotation(30),
                                   transforms.RandomResizedCrop(224),
                                   transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485,0.456,0.406],
                                                    [0.229,0.224,0.225])]),
                   "test":transforms.Compose([transforms.Resize(255),
                                  transforms.CenterCrop(224),
                                  transforms.ToTensor(),
                                 transforms.Normalize([0.485, 0.456, 0.406],
                                                   [0.229, 0.224, 0.225])])

                  }
'''train_transforms=transforms.Compose([transforms.RandomRotation(30),
                                   transforms.RandomResizedCrop(224),
                                   transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485,0.456,0.406],
                                                    [0.229,0.224,0.225])])
validation_transforms = transforms.Compose([transforms.Resize(255),
                                  transforms.CenterCrop(224),
                                  transforms.ToTensor(),
                                 transforms.Normalize([0.485, 0.456, 0.406],
                                                   [0.229, 0.224, 0.225])])
test_transforms = transforms.Compose([transforms.Resize(255),
                                  transforms.CenterCrop(224),
                                  transforms.ToTensor(),
                                 transforms.Normalize([0.485, 0.456, 0.406],
                                                   [0.229, 0.224, 0.225])])'''




# TODO: Load the datasets with ImageFolder
image_datasets = {"train" : datasets.ImageFolder(train_dir,transform=data_transforms['train']),
                  "validation": datasets.ImageFolder(valid_dir, transform=data_transforms['validation']),
                  "test":datasets.ImageFolder(test_dir, transform=data_transforms['test'])}
    


#train_datasets = datasets.ImageFolder(train_dir,transform=train_transforms)
#validation_datasets = datasets.ImageFolder(valid_dir, transform=validation_transforms)
#test_datasets = datasets.ImageFolder(test_dir, transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {"train":torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True),
               "validation":torch.utils.data.DataLoader(image_datasets['validation'], batch_size=64),
               "test":torch.utils.data.DataLoader(image_datasets['test'],batch_size=64)
    
}
#trainloader = torch.utils.data.DataLoader(train_datasets, batch_size=64, shuffle=True)
#validationloader = torch.utils.data.DataLoader(validation_datasets, batch_size=64)
#testloader = torch.utils.data.DataLoader(test_datasets,batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
#load pre-train model
mymodel=models.vgg16(pretrained=True)
mymodel
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
#freeeze parameters in mymodel
for param in mymodel.parameters():
    param.requires_grad=False

#Define a new, untrained feed-forward network as a classifier
mymodel.classifier=nn.Sequential(nn.Linear(25088,4096),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(4096,4096),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(4096,510),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(510,102),
                              nn.LogSoftmax(dim=1))

# %%
#set up criterion, optimzier and enable GPu 
criterion = nn.NLLLoss()
optimizer = optim.Adam(mymodel.classifier.parameters(), lr=0.001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
mymodel.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=4096, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2)
#     (9): Linear(in_features=510, out_features=102, bias=True)
#     (10): LogSoftmax()
#   )
# )

# %%
epochs = 10
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in dataloaders['train']:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        logps = mymodel.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            mymodel.eval()
            with torch.no_grad():
                for inputs, labels in dataloaders['validation']:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = mymodel.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(dataloaders['validation']):.3f}.. "
                  f"Test accuracy: {accuracy/len(dataloaders['validation']):.3f}")
            running_loss = 0
            mymodel.train()
# Out:
# Epoch 1/10.. Train loss: 5.042.. Test loss: 4.583.. Test accuracy: 0.034
# Epoch 1/10.. Train loss: 4.555.. Test loss: 4.504.. Test accuracy: 0.051
# Epoch 1/10.. Train loss: 4.416.. Test loss: 4.367.. Test accuracy: 0.070
# Epoch 1/10.. Train loss: 4.292.. Test loss: 4.161.. Test accuracy: 0.097
# Epoch 1/10.. Train loss: 4.137.. Test loss: 4.019.. Test accuracy: 0.137
# Epoch 1/10.. Train loss: 4.037.. Test loss: 3.769.. Test accuracy: 0.158
# Epoch 1/10.. Train loss: 3.882.. Test loss: 3.604.. Test accuracy: 0.197
# Epoch 1/10.. Train loss: 3.665.. Test loss: 3.401.. Test accuracy: 0.237
# Epoch 1/10.. Train loss: 3.558.. Test loss: 3.227.. Test accuracy: 0.272
# Epoch 1/10.. Train loss: 3.289.. Test loss: 3.100.. Test accuracy: 0.267
# Epoch 1/10.. Train loss: 3.132.. Test loss: 2.936.. Test accuracy: 0.296
# Epoch 1/10.. Train loss: 2.933.. Test loss: 2.718.. Test accuracy: 0.335
# Epoch 1/10.. Train loss: 2.691.. Test loss: 2.615.. Test accuracy: 0.359
# Epoch 1/10.. Train loss: 2.661.. Test loss: 2.507.. Test accuracy: 0.376
# Epoch 1/10.. Train loss: 2.675.. Test loss: 2.462.. Test accuracy: 0.374
# Epoch 1/10.. Train loss: 2.572.. Test loss: 2.304.. Test accuracy: 0.403
# Epoch 1/10.. Train loss: 2.536.. Test loss: 2.179.. Test accuracy: 0.431
# Epoch 1/10.. Train loss: 2.582.. Test loss: 2.266.. Test accuracy: 0.419
# Epoch 1/10.. Train loss: 2.422.. Test loss: 2.162.. Test accuracy: 0.434
# Epoch 1/10.. Train loss: 2.306.. Test loss: 2.127.. Test accuracy: 0.438
# Epoch 2/10.. Train loss: 2.188.. Test loss: 2.103.. Test accuracy: 0.440
# Epoch 2/10.. Train loss: 1.974.. Test loss: 1.882.. Test accuracy: 0.488
# Epoch 2/10.. Train loss: 2.044.. Test loss: 1.926.. Test accuracy: 0.497
# Epoch 2/10.. Train loss: 1.888.. Test loss: 1.808.. Test accuracy: 0.525
# Epoch 2/10.. Train loss: 1.940.. Test loss: 1.829.. Test accuracy: 0.524
# Epoch 2/10.. Train loss: 2.026.. Test loss: 1.839.. Test accuracy: 0.512
# Epoch 2/10.. Train loss: 2.065.. Test loss: 1.793.. Test accuracy: 0.527
# Epoch 2/10.. Train loss: 1.815.. Test loss: 1.818.. Test accuracy: 0.553
# Epoch 2/10.. Train loss: 2.008.. Test loss: 1.678.. Test accuracy: 0.537
# Epoch 2/10.. Train loss: 1.932.. Test loss: 1.796.. Test accuracy: 0.531
# Epoch 2/10.. Train loss: 1.966.. Test loss: 1.661.. Test accuracy: 0.576
# Epoch 2/10.. Train loss: 1.698.. Test loss: 1.666.. Test accuracy: 0.539
# Epoch 2/10.. Train loss: 1.833.. Test loss: 1.639.. Test accuracy: 0.541
# Epoch 2/10.. Train loss: 1.836.. Test loss: 1.561.. Test accuracy: 0.573
# Epoch 2/10.. Train loss: 1.852.. Test loss: 1.571.. Test accuracy: 0.586
# Epoch 2/10.. Train loss: 1.782.. Test loss: 1.550.. Test accuracy: 0.590
# Epoch 2/10.. Train loss: 1.677.. Test loss: 1.520.. Test accuracy: 0.585
# Epoch 2/10.. Train loss: 1.635.. Test loss: 1.539.. Test accuracy: 0.591
# Epoch 2/10.. Train loss: 1.744.. Test loss: 1.531.. Test accuracy: 0.588
# Epoch 2/10.. Train loss: 1.703.. Test loss: 1.391.. Test accuracy: 0.635
# Epoch 2/10.. Train loss: 1.765.. Test loss: 1.470.. Test accuracy: 0.607
# Epoch 3/10.. Train loss: 1.642.. Test loss: 1.415.. Test accuracy: 0.626
# Epoch 3/10.. Train loss: 1.564.. Test loss: 1.453.. Test accuracy: 0.614
# Epoch 3/10.. Train loss: 1.502.. Test loss: 1.429.. Test accuracy: 0.599
# Epoch 3/10.. Train loss: 1.608.. Test loss: 1.431.. Test accuracy: 0.623
# Epoch 3/10.. Train loss: 1.493.. Test loss: 1.371.. Test accuracy: 0.626
# Epoch 3/10.. Train loss: 1.533.. Test loss: 1.453.. Test accuracy: 0.619
# Epoch 3/10.. Train loss: 1.439.. Test loss: 1.340.. Test accuracy: 0.634
# Epoch 3/10.. Train loss: 1.620.. Test loss: 1.348.. Test accuracy: 0.645
# Epoch 3/10.. Train loss: 1.566.. Test loss: 1.363.. Test accuracy: 0.640
# Epoch 3/10.. Train loss: 1.542.. Test loss: 1.225.. Test accuracy: 0.691
# Epoch 3/10.. Train loss: 1.400.. Test loss: 1.288.. Test accuracy: 0.662
# Epoch 3/10.. Train loss: 1.312.. Test loss: 1.223.. Test accuracy: 0.673
# Epoch 3/10.. Train loss: 1.317.. Test loss: 1.212.. Test accuracy: 0.682
# Epoch 3/10.. Train loss: 1.473.. Test loss: 1.241.. Test accuracy: 0.672
# Epoch 3/10.. Train loss: 1.283.. Test loss: 1.271.. Test accuracy: 0.646
# Epoch 3/10.. Train loss: 1.396.. Test loss: 1.174.. Test accuracy: 0.674
# Epoch 3/10.. Train loss: 1.287.. Test loss: 1.228.. Test accuracy: 0.655
# Epoch 3/10.. Train loss: 1.354.. Test loss: 1.278.. Test accuracy: 0.648
# Epoch 3/10.. Train loss: 1.403.. Test loss: 1.246.. Test accuracy: 0.660
# Epoch 3/10.. Train loss: 1.408.. Test loss: 1.285.. Test accuracy: 0.661
# Epoch 4/10.. Train loss: 1.533.. Test loss: 1.175.. Test accuracy: 0.686
# Epoch 4/10.. Train loss: 1.438.. Test loss: 1.236.. Test accuracy: 0.652
# Epoch 4/10.. Train loss: 1.268.. Test loss: 1.223.. Test accuracy: 0.674
# Epoch 4/10.. Train loss: 1.532.. Test loss: 1.244.. Test accuracy: 0.668
# Epoch 4/10.. Train loss: 1.270.. Test loss: 1.256.. Test accuracy: 0.677
# Epoch 4/10.. Train loss: 1.164.. Test loss: 1.266.. Test accuracy: 0.673
# Epoch 4/10.. Train loss: 1.240.. Test loss: 1.214.. Test accuracy: 0.661
# Epoch 4/10.. Train loss: 1.208.. Test loss: 1.245.. Test accuracy: 0.677
# Epoch 4/10.. Train loss: 1.249.. Test loss: 1.176.. Test accuracy: 0.694
# Epoch 4/10.. Train loss: 1.283.. Test loss: 1.176.. Test accuracy: 0.691
# Epoch 4/10.. Train loss: 1.237.. Test loss: 1.132.. Test accuracy: 0.692
# Epoch 4/10.. Train loss: 1.159.. Test loss: 1.225.. Test accuracy: 0.674
# Epoch 4/10.. Train loss: 1.097.. Test loss: 1.196.. Test accuracy: 0.680
# Epoch 4/10.. Train loss: 1.161.. Test loss: 1.161.. Test accuracy: 0.687
# Epoch 4/10.. Train loss: 1.134.. Test loss: 1.235.. Test accuracy: 0.677
# Epoch 4/10.. Train loss: 1.195.. Test loss: 1.205.. Test accuracy: 0.682
# Epoch 4/10.. Train loss: 1.191.. Test loss: 1.259.. Test accuracy: 0.667
# Epoch 4/10.. Train loss: 1.274.. Test loss: 1.110.. Test accuracy: 0.695
# Epoch 4/10.. Train loss: 1.169.. Test loss: 1.156.. Test accuracy: 0.679
# Epoch 4/10.. Train loss: 1.197.. Test loss: 1.063.. Test accuracy: 0.719
# Epoch 4/10.. Train loss: 1.176.. Test loss: 1.095.. Test accuracy: 0.706
# Epoch 5/10.. Train loss: 1.155.. Test loss: 1.147.. Test accuracy: 0.697
# Epoch 5/10.. Train loss: 1.144.. Test loss: 1.135.. Test accuracy: 0.694
# Epoch 5/10.. Train loss: 1.160.. Test loss: 1.122.. Test accuracy: 0.710
# Epoch 5/10.. Train loss: 1.244.. Test loss: 1.085.. Test accuracy: 0.712
# Epoch 5/10.. Train loss: 1.230.. Test loss: 1.099.. Test accuracy: 0.711
# Epoch 5/10.. Train loss: 1.239.. Test loss: 1.153.. Test accuracy: 0.714
# Epoch 5/10.. Train loss: 1.235.. Test loss: 1.096.. Test accuracy: 0.719
# Epoch 5/10.. Train loss: 1.099.. Test loss: 1.078.. Test accuracy: 0.709
# Epoch 5/10.. Train loss: 1.099.. Test loss: 1.120.. Test accuracy: 0.701
# Epoch 5/10.. Train loss: 1.120.. Test loss: 1.167.. Test accuracy: 0.683
# Epoch 5/10.. Train loss: 1.073.. Test loss: 1.033.. Test accuracy: 0.727
# Epoch 5/10.. Train loss: 1.077.. Test loss: 1.098.. Test accuracy: 0.711
# Epoch 5/10.. Train loss: 1.476.. Test loss: 1.126.. Test accuracy: 0.707
# Epoch 5/10.. Train loss: 1.195.. Test loss: 1.080.. Test accuracy: 0.722
# Epoch 5/10.. Train loss: 1.147.. Test loss: 1.098.. Test accuracy: 0.714
# Epoch 5/10.. Train loss: 1.152.. Test loss: 1.049.. Test accuracy: 0.707
# Epoch 5/10.. Train loss: 1.225.. Test loss: 1.036.. Test accuracy: 0.725
# Epoch 5/10.. Train loss: 1.015.. Test loss: 1.086.. Test accuracy: 0.712
# Epoch 5/10.. Train loss: 1.014.. Test loss: 1.028.. Test accuracy: 0.723
# Epoch 5/10.. Train loss: 1.052.. Test loss: 1.084.. Test accuracy: 0.707
# Epoch 5/10.. Train loss: 0.885.. Test loss: 0.942.. Test accuracy: 0.741
# Epoch 6/10.. Train loss: 0.934.. Test loss: 1.058.. Test accuracy: 0.720
# Epoch 6/10.. Train loss: 0.941.. Test loss: 1.076.. Test accuracy: 0.706
# Epoch 6/10.. Train loss: 1.108.. Test loss: 1.136.. Test accuracy: 0.688
# Epoch 6/10.. Train loss: 1.115.. Test loss: 0.999.. Test accuracy: 0.733
# Epoch 6/10.. Train loss: 1.135.. Test loss: 1.092.. Test accuracy: 0.702
# Epoch 6/10.. Train loss: 1.059.. Test loss: 1.094.. Test accuracy: 0.705
# Epoch 6/10.. Train loss: 1.091.. Test loss: 1.100.. Test accuracy: 0.727
# Epoch 6/10.. Train loss: 1.158.. Test loss: 1.024.. Test accuracy: 0.720
# Epoch 6/10.. Train loss: 1.119.. Test loss: 1.076.. Test accuracy: 0.707
# Epoch 6/10.. Train loss: 1.025.. Test loss: 1.079.. Test accuracy: 0.734
# Epoch 6/10.. Train loss: 0.998.. Test loss: 1.124.. Test accuracy: 0.707
# Epoch 6/10.. Train loss: 1.206.. Test loss: 0.973.. Test accuracy: 0.742
# Epoch 6/10.. Train loss: 1.084.. Test loss: 1.135.. Test accuracy: 0.714
# Epoch 6/10.. Train loss: 1.351.. Test loss: 1.025.. Test accuracy: 0.732
# Epoch 6/10.. Train loss: 1.217.. Test loss: 1.060.. Test accuracy: 0.733
# Epoch 6/10.. Train loss: 1.140.. Test loss: 1.009.. Test accuracy: 0.732
# Epoch 6/10.. Train loss: 1.184.. Test loss: 1.026.. Test accuracy: 0.735
# Epoch 6/10.. Train loss: 0.947.. Test loss: 1.014.. Test accuracy: 0.727
# Epoch 6/10.. Train loss: 1.239.. Test loss: 0.979.. Test accuracy: 0.737
# Epoch 6/10.. Train loss: 1.017.. Test loss: 0.985.. Test accuracy: 0.736
# Epoch 7/10.. Train loss: 1.032.. Test loss: 0.926.. Test accuracy: 0.749
# Epoch 7/10.. Train loss: 0.917.. Test loss: 0.991.. Test accuracy: 0.752
# Epoch 7/10.. Train loss: 0.863.. Test loss: 0.967.. Test accuracy: 0.730
# Epoch 7/10.. Train loss: 0.873.. Test loss: 0.942.. Test accuracy: 0.775
# Epoch 7/10.. Train loss: 1.029.. Test loss: 0.961.. Test accuracy: 0.760
# Epoch 7/10.. Train loss: 1.109.. Test loss: 0.805.. Test accuracy: 0.794
# Epoch 7/10.. Train loss: 0.995.. Test loss: 0.951.. Test accuracy: 0.743
# Epoch 7/10.. Train loss: 0.947.. Test loss: 0.974.. Test accuracy: 0.743
# Epoch 7/10.. Train loss: 1.187.. Test loss: 1.016.. Test accuracy: 0.726
# Epoch 7/10.. Train loss: 1.144.. Test loss: 0.973.. Test accuracy: 0.741
# Epoch 7/10.. Train loss: 1.192.. Test loss: 0.976.. Test accuracy: 0.744
# Epoch 7/10.. Train loss: 1.108.. Test loss: 0.998.. Test accuracy: 0.736
# Epoch 7/10.. Train loss: 1.005.. Test loss: 0.992.. Test accuracy: 0.739
# Epoch 7/10.. Train loss: 0.852.. Test loss: 0.919.. Test accuracy: 0.764
# Epoch 7/10.. Train loss: 1.135.. Test loss: 0.923.. Test accuracy: 0.755
# Epoch 7/10.. Train loss: 0.950.. Test loss: 0.963.. Test accuracy: 0.732
# Epoch 7/10.. Train loss: 1.095.. Test loss: 1.031.. Test accuracy: 0.748
# Epoch 7/10.. Train loss: 0.913.. Test loss: 0.927.. Test accuracy: 0.749
# Epoch 7/10.. Train loss: 1.182.. Test loss: 1.038.. Test accuracy: 0.729
# Epoch 7/10.. Train loss: 1.034.. Test loss: 0.964.. Test accuracy: 0.760
# Epoch 7/10.. Train loss: 1.146.. Test loss: 1.059.. Test accuracy: 0.720
# Epoch 8/10.. Train loss: 1.020.. Test loss: 1.065.. Test accuracy: 0.711
# Epoch 8/10.. Train loss: 1.035.. Test loss: 0.994.. Test accuracy: 0.743
# Epoch 8/10.. Train loss: 1.157.. Test loss: 1.027.. Test accuracy: 0.738
# Epoch 8/10.. Train loss: 1.083.. Test loss: 0.963.. Test accuracy: 0.740
# Epoch 8/10.. Train loss: 0.922.. Test loss: 0.901.. Test accuracy: 0.764
# Epoch 8/10.. Train loss: 0.958.. Test loss: 0.924.. Test accuracy: 0.756
# Epoch 8/10.. Train loss: 0.860.. Test loss: 0.898.. Test accuracy: 0.765
# Epoch 8/10.. Train loss: 0.786.. Test loss: 0.992.. Test accuracy: 0.747
# Epoch 8/10.. Train loss: 1.003.. Test loss: 0.935.. Test accuracy: 0.762
# Epoch 8/10.. Train loss: 0.938.. Test loss: 0.847.. Test accuracy: 0.784
# Epoch 8/10.. Train loss: 1.025.. Test loss: 0.916.. Test accuracy: 0.766
# Epoch 8/10.. Train loss: 1.013.. Test loss: 0.908.. Test accuracy: 0.767
# Epoch 8/10.. Train loss: 0.939.. Test loss: 0.960.. Test accuracy: 0.750
# Epoch 8/10.. Train loss: 0.981.. Test loss: 0.893.. Test accuracy: 0.765
# Epoch 8/10.. Train loss: 0.786.. Test loss: 0.877.. Test accuracy: 0.779
# Epoch 8/10.. Train loss: 1.018.. Test loss: 0.861.. Test accuracy: 0.769
# Epoch 8/10.. Train loss: 0.902.. Test loss: 0.933.. Test accuracy: 0.754
# Epoch 8/10.. Train loss: 0.791.. Test loss: 0.999.. Test accuracy: 0.744
# Epoch 8/10.. Train loss: 0.975.. Test loss: 0.852.. Test accuracy: 0.773
# Epoch 8/10.. Train loss: 0.838.. Test loss: 0.962.. Test accuracy: 0.763
# Epoch 9/10.. Train loss: 1.067.. Test loss: 0.895.. Test accuracy: 0.767
# Epoch 9/10.. Train loss: 0.778.. Test loss: 0.916.. Test accuracy: 0.776
# Epoch 9/10.. Train loss: 0.924.. Test loss: 0.853.. Test accuracy: 0.774
# Epoch 9/10.. Train loss: 0.788.. Test loss: 0.779.. Test accuracy: 0.799
# Epoch 9/10.. Train loss: 0.757.. Test loss: 0.819.. Test accuracy: 0.802
# Epoch 9/10.. Train loss: 0.943.. Test loss: 0.874.. Test accuracy: 0.763
# Epoch 9/10.. Train loss: 0.988.. Test loss: 0.957.. Test accuracy: 0.755
# Epoch 9/10.. Train loss: 0.777.. Test loss: 0.881.. Test accuracy: 0.754
# Epoch 9/10.. Train loss: 0.926.. Test loss: 1.004.. Test accuracy: 0.738
# Epoch 9/10.. Train loss: 1.115.. Test loss: 0.784.. Test accuracy: 0.803
# Epoch 9/10.. Train loss: 0.792.. Test loss: 0.846.. Test accuracy: 0.776
# Epoch 9/10.. Train loss: 0.854.. Test loss: 0.896.. Test accuracy: 0.769
# Epoch 9/10.. Train loss: 0.725.. Test loss: 0.781.. Test accuracy: 0.792
# Epoch 9/10.. Train loss: 0.945.. Test loss: 0.786.. Test accuracy: 0.795
# Epoch 9/10.. Train loss: 0.931.. Test loss: 0.850.. Test accuracy: 0.770
# Epoch 9/10.. Train loss: 0.892.. Test loss: 0.877.. Test accuracy: 0.773
# Epoch 9/10.. Train loss: 0.845.. Test loss: 0.853.. Test accuracy: 0.781
# Epoch 9/10.. Train loss: 0.935.. Test loss: 0.985.. Test accuracy: 0.756
# Epoch 9/10.. Train loss: 1.142.. Test loss: 0.973.. Test accuracy: 0.775
# Epoch 9/10.. Train loss: 0.951.. Test loss: 0.894.. Test accuracy: 0.771
# Epoch 9/10.. Train loss: 0.816.. Test loss: 0.942.. Test accuracy: 0.765
# Epoch 10/10.. Train loss: 0.861.. Test loss: 0.886.. Test accuracy: 0.778
# Epoch 10/10.. Train loss: 0.944.. Test loss: 0.895.. Test accuracy: 0.767
# Epoch 10/10.. Train loss: 0.845.. Test loss: 0.911.. Test accuracy: 0.766
# Epoch 10/10.. Train loss: 1.072.. Test loss: 0.970.. Test accuracy: 0.772
# Epoch 10/10.. Train loss: 0.960.. Test loss: 0.958.. Test accuracy: 0.769
# Epoch 10/10.. Train loss: 0.941.. Test loss: 0.896.. Test accuracy: 0.785
# Epoch 10/10.. Train loss: 0.871.. Test loss: 0.950.. Test accuracy: 0.760
# Epoch 10/10.. Train loss: 0.995.. Test loss: 0.898.. Test accuracy: 0.762
# Epoch 10/10.. Train loss: 0.853.. Test loss: 0.957.. Test accuracy: 0.757
# Epoch 10/10.. Train loss: 0.957.. Test loss: 0.918.. Test accuracy: 0.767
# Epoch 10/10.. Train loss: 0.859.. Test loss: 0.811.. Test accuracy: 0.808
# Epoch 10/10.. Train loss: 0.959.. Test loss: 0.875.. Test accuracy: 0.782
# Epoch 10/10.. Train loss: 0.819.. Test loss: 0.767.. Test accuracy: 0.798
# Epoch 10/10.. Train loss: 0.739.. Test loss: 0.905.. Test accuracy: 0.775
# Epoch 10/10.. Train loss: 0.800.. Test loss: 0.859.. Test accuracy: 0.792
# Epoch 10/10.. Train loss: 0.731.. Test loss: 0.863.. Test accuracy: 0.779
# Epoch 10/10.. Train loss: 0.815.. Test loss: 0.901.. Test accuracy: 0.775
# Epoch 10/10.. Train loss: 0.982.. Test loss: 0.853.. Test accuracy: 0.788
# Epoch 10/10.. Train loss: 0.821.. Test loss: 0.928.. Test accuracy: 0.762
# Epoch 10/10.. Train loss: 0.629.. Test loss: 0.917.. Test accuracy: 0.764
# Epoch 10/10.. Train loss: 0.939.. Test loss: 0.904.. Test accuracy: 0.760

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
accuracy = 0
mymodel.eval()
with torch.no_grad():
    for inputs, labels in dataloaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = mymodel.forward(inputs)
        batch_loss = criterion(logps, labels)
                    
        test_loss += batch_loss.item()
                    
        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
print(
      f"Test loss: {test_loss/len(dataloaders['test']):.3f}.. "
      f"Test accuracy: {accuracy/len(dataloaders['test']):.3f}")

mymodel.train()
# Out:
# Test loss: 0.567.. Test accuracy: 0.850
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=4096, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2)
#     (9): Linear(in_features=510, out_features=102, bias=True)
#     (10): LogSoftmax()
#   )
# )

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
mymodel.class_to_idx = image_datasets['train'].class_to_idx
checkpoint={'input_size':25088,
           'output_size':102,
            'hidden_layer':[4096,4096,510],
            'state_dict':mymodel.state_dict(),
            'class_to_idx':mymodel.class_to_idx,
            'opimizer':optimizer.state_dict(),
            'epochs_num':10,
            'arch':'vgg16'
           }
torch.save(checkpoint, 'mymodelcheckpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
#load checkpoint
def checkpointfunction(checkpoint):
    #load the checkpoint.pth file, the input needs to be a string of checkpoint
    #name
    newcheckpoint=torch.load(checkpoint)
    
    if newcheckpoint['arch'] == 'vgg16':
        newmymodel = models.vgg16(pretrained=True)
        #freeze parameters in mynewmodel
        for param in newmymodel.parameters():
            param.requires_grad=False
    else:
        print("only vgg16 structure is allowed")
    
    newmymodel.class_to_idx = newcheckpoint['class_to_idx']
    
    if len(newcheckpoint['hidden_layer']) == 3:
        newmymodel.classifier=nn.Sequential(nn.Linear(newcheckpoint['input_size'],newcheckpoint['hidden_layer'][0]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][0],newcheckpoint['hidden_layer'][1]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][1],newcheckpoint['hidden_layer'][2]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][2],newcheckpoint['output_size']),
                              nn.LogSoftmax(dim=1))
        newmymodel.load_state_dict(newcheckpoint['state_dict'])
    else:
        print("the checkpoint needs to have 3 hidden layer")
    
    return newmymodel
    
 

"""#newcheckpoint = torch.load('mymodelcheckpoint.pth')
#constrcut a new model

#newmymodel=models.vgg16(pretrained=True)
#freeeze parameters in mymodel
#for param in newmymodel.parameters():
    param.requires_grad=False

#Define a new, untrained feed-forward network as a classifier
#newmymodel.classifier=nn.Sequential(nn.Linear(newcheckpoint['input_size'],newcheckpoint['hidden_layer'][0]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][0],newcheckpoint['hidden_layer'][1]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][1],newcheckpoint['hidden_layer'][2]),
                              nn.ReLU(),
                              nn.Dropout(0.2),
                              nn.Linear(newcheckpoint['hidden_layer'][2],newcheckpoint['output_size']),
                              nn.LogSoftmax(dim=1))
                                            
#newmymodel.load_state_dict(newcheckpoint['state_dict'])


newmymodel.class_to_idx = newcheckpoint['class_to_idx']
newmymodel.to(device)
newmymodel
"""
# Out:
# "#newcheckpoint = torch.load('mymodelcheckpoint.pth')\n#constrcut a new model\n\n#newmymodel=models.vgg16(pretrained=True)\n#freeeze parameters in mymodel\n#for param in newmymodel.parameters():\n    param.requires_grad=False\n\n#Define a new, untrained feed-forward network as a classifier\n#newmymodel.classifier=nn.Sequential(nn.Linear(newcheckpoint['input_size'],newcheckpoint['hidden_layer'][0]),\n                              nn.ReLU(),\n                              nn.Dropout(0.2),\n                              nn.Linear(newcheckpoint['hidden_layer'][0],newcheckpoint['hidden_layer'][1]),\n                              nn.ReLU(),\n                              nn.Dropout(0.2),\n                              nn.Linear(newcheckpoint['hidden_layer'][1],newcheckpoint['hidden_layer'][2]),\n                              nn.ReLU(),\n                              nn.Dropout(0.2),\n                              nn.Linear(newcheckpoint['hidden_layer'][2],newcheckpoint['output_size']),\n                              nn.LogSoftmax(dim=1))\n                                            \n#newmymodel.load_state_dict(newcheckpoint['state_dict'])\n\n\nnewmymodel.class_to_idx = newcheckpoint['class_to_idx']\nnewmymodel.to(device)\nnewmymodel\n"

# %%
newmymodel=checkpointfunction('mymodelcheckpoint.pth')
newmymodel.to(device)
newmymodel
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=4096, out_features=510, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2)
#     (9): Linear(in_features=510, out_features=102, bias=True)
#     (10): LogSoftmax()
#   )
# )

# %%
#use the validation data set to double check whether the save checkpoint is sucessfully loaded or not
test_loss = 0
accuracy = 0
newmymodel.eval()
with torch.no_grad():
    for inputs, labels in dataloaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = newmymodel.forward(inputs)
        batch_loss = criterion(logps, labels)
                    
        test_loss += batch_loss.item()
                    
        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
print(
      f"Test loss: {test_loss/len(dataloaders['test']):.3f}.. "
      f"Test accuracy: {accuracy/len(dataloaders['test']):.3f}")
# Out:
# Test loss: 0.567.. Test accuracy: 0.850

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    Image_loader = transforms.Compose([
        transforms.Resize(256), 
        transforms.CenterCrop(224), 
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
    
    pil_image = Image.open(image)
    pil_image = Image_loader(pil_image)
    
    #np_image = pil_image.numpy().transpose((1,2,0))
    
    #np_image = np.array(pil_image)    
    
    #mean = np.array([0.485, 0.456, 0.406])
    #std = np.array([0.229, 0.224, 0.225])
    #np_image was 3,224,224, now change the shape of np_image to 224,224,3 in order to do the normalization
    #np_image = (np.transpose(np_image,(1,2,0))-mean)/std
    #change np_image back to 3, 244,244
    #np_image = np.transpose(np_image,(2,0,1))  
    
                            
    return pil_image

test=process_image('image_07090.jpg')
print(test.shape)
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # switch the color channel to third dimension, in order to make matplot lib works.
    image=image.numpy().transpose((1, 2, 0))
    
    # restore the normilization
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %matplotlib inline

_= imshow(process_image('image_07090.jpg'))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    image_inputs = process_image(image_path)
   
    image_inputs=image_inputs.unsqueeze(0)
    image_inputs = image_inputs.float()
    
    

    
    with torch.no_grad():
        ps = torch.exp(model.forward(image_inputs.cuda()))
        
    top_p, top_class = ps.topk(topk, dim=1)
    
    return top_p, top_class

# %%
image_path = 'image_07090.jpg'

top_p, top_classes = predict(image_path, newmymodel)
print(top_p)
print(top_classes)

print(np.array(top_p[0]))
# Out:
# tensor([[ 0.9959,  0.0031,  0.0007,  0.0001,  0.0001]], device='cuda:0')
# tensor([[  1,  48,   8,  94,   6]], device='cuda:0')
# [  9.95896161e-01   3.10358615e-03   7.18986150e-04   9.38966041e-05
#    8.24880772e-05]

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# %matplotlib inline
from matplotlib.ticker import FormatStrFormatter
image_path = test_dir + '/1/image_06743.jpg'

topk_p, topk_c = predict(image_path, newmymodel)

print(topk_c)


index = 1
image_input = process_image(image_path)



ax1 = imshow(image_input, ax = plt)
ax1.axis('off')
ax1.title(cat_to_name[str(index)])
ax1.show()

fig,ax2 = plt.subplots(figsize=(8,3))
probability = np.array(topk_p[0])
labels = [cat_to_name[str(index+1)] for index in np.array(topk_c[0])]
number_of_labels = float(len(labels))
print(labels[0])


ax2.bar(np.arange(number_of_labels), probability,align = 'center')
ax2.set_xticks(np.arange(number_of_labels))
ax2.set_xticklabels(labels)
ax2.set_yticks([0.2,0.4,0.6,0.8,1])

ax2.yaxis.grid(True)
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# Out:
# tensor([[   0,   84,   87,   95,  100]], device='cuda:0')
# pink primrose
